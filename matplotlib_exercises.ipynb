# %%
import matplotlib.pyplot as plt

# %%
x = list(range(150))
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(range(len(x)),x)
plt.show()

# %%
plt.plot(x)
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.show()

# %%
plt.plot(x, c='red')
plt.show()

# %%
from random import randint 
x1 = [randint(-5,25) + n for n in range(150)]
x2 = [x + randint(-6,6) for x in x1]

plt.plot(x1,alpha =0.5)
plt.plot(x2,alpha =0.4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(range(len(x1)), x1)
plt.scatter(range(len(x2)), x2)
plt.show()

# %% [markdown]
# ## Exercises
# Use matplotlib to plot the following equation:
#
# y=x2−x+2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
from math import pow

x_values = range(-50,50)
y_values = [(pow(x,2)-x+2)for x in x_values]

plt.plot(x_values,y_values)
plt.show()

# %% [markdown]
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %%
from math import sqrt
x_values = range(1,50)
y_values =[(sqrt(x)) for x in x_values]
plt.plot(x_values,y_values)
plt.show()

# %%
from math import pow
x_values = range(1,50)
y_values =[(pow(x,3)) for x in x_values]
plt.plot(x_values,y_values)
plt.show()

# %%
from math import pow
x_values = range(1,10)
y_values =[(pow(2,x)) for x in x_values]
plt.plot(x_values,y_values)
plt.show()

# %%
x_values = range(1,10)
y_values =[(1/(x+1)) for x in x_values]
plt.plot(x_values,y_values,label='$y^x$')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
n_rows = 2
n_cols = 4

# %%
# plot the first subplot
x_values = range(1,10)
y_values= [(sqrt(x)) for x in x_values]
plt.subplot(241)
plt.plot(x_values, y_values,c='blue',)
plt.title("1")

#plot the second subplot 
x_values = range(1,10)
y_values= [(pow(2,x)) for x in x_values]
plt.subplot(242)
plt.plot(x_values, y_values,c='red')
plt.title("2")

#plot the third subplot
x_values = range(1,10)
y_values =[(1/(x+1)) for x in x_values]
plt.subplot(243)
plt.plot(x_values, y_values, c='orange')
plt.title("3")

#plot the forth subplot
x_values = range(1,50)
y_values =[(pow(x,3)) for x in x_values]
plt.subplot(244)
plt.plot(x_values, y_values,c='green')
plt.title("4")
# Out:
# Text(0.5, 1.0, '4')

# %%
# plot the first subplot
x_values = range(1,10)


y_values1= [(sqrt(x)) for x in x_values]
y_values2= [(pow(2,x)) for x in x_values]
y_values3 =[(1/(x+1)) for x in x_values]
y_values4 =[(pow(x,3)) for x in x_values]



plt.plot(x_values, y_values1,c='blue', label = 'sqrt(x)')
plt.plot(x_values, y_values2,c='red', label = '$2^n$')
plt.plot(x_values, y_values3, c='orange',label = '1/(x+1)')
plt.plot(x_values, y_values4,c='green',label = '$x^3$')


plt.legend()
plt.show()
