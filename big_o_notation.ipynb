# %% [markdown]
# # Make a new Jupyter notebook named big_o_notation.ipynb

# %% [markdown]
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible

# %%
import matplotlib.pyplot as plt
import math

# %%
x = [1,2,3,4,5,6,7]
y = [8,9,10,11,12,13,14]

# %%
plt.plot(x, y,linestyle = '--',label = 'legend here')
plt.title('$Big O Notation$')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()

# %% [markdown]
# y= 0*n +1 and label the curve "O(1)"

# %%
# define a range of x
x = range(1, 5)

# use a list comprehension to describe x * 0 +1 for every x as we defined it
y1 = [ (n * 0 +1) for n in x]
y2 = [math.log(n) for n in x]
y3 = [ n for n in x]
y4 = [ (n* math.log(n)) for n in x]
y5 = [ (n**2) for n in x]
y6 = [ (2**n) for n in x]
y7 = [ math.factorial(n) for n in x]



plt.plot(x,y7, label='O(${n!}$)')
plt.plot(x,y6, label='O(2^n)')
plt.plot(x,y5, label='O$(n^2)$')
plt.plot(x,y4, label='O(n $\log{n}$)')
plt.plot(x,y3, label='O(n)')
plt.plot(x,y2, label='O($\log{n}$)')
plt.plot(x,y1, label='O(1)')

plt.title('$Big O Notation$')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()
plt.show()

# %% [markdown]
# y=log(n) and label the curve "O(log n)"

# %% [markdown]
# y = n* log(n) and label it "O(n log n)

# %% [markdown]
# y = n**2and label it "O(n^2)"

# %% [markdown]
# y = 2**n and label it "O(2^n)"

# %%
x = range(1, 10)

# use a list comprehension to describe x * 0 +1 for every x as we defined it
y6 = [ (2**n) for n in x]

plt.plot(x,y6, label='O$(2^n)$')
plt.legend()
plt.show()

# %% [markdown]
# y = n! and label it "O(n!)"

# %%
x = range(1, 10)

# use a list comprehension to describe x * 0 +1 for every x as we defined it
y7 = [ math.factorial(n) for n in x]

plt.plot(x,y7, label='O(${n!}$)')

plt.legend()
plt.show()

# %% [markdown]
# y= n**n and label it "O(n^n)"

# %%
x = range(1,10)

# use a list comprehension to describe for every x as we defined it
y8 = [ n** n for n in x]

plt.plot(x,y8, label='O$(n^n)$')
plt.legend()
plt.show()
